# %% [markdown]
# # Introduction
#
# Data visualization helps transform raw data into meaningful insights through charts, graphs, and visual storytelling. This project analyzes Superstore sales data using various visualizations to understand sales performance, profitability, customer segments, and regional trends.
#
# The project aims to support decision-making by presenting business insights through effective visualizations.

# %% [markdown]
# # Problem Statement
#
# Businesses generate large amounts of sales data, making it difficult to identify important trends and patterns. Visualizing sales data helps organizations understand performance, identify profitable areas, and make informed business decisions.

# %% [markdown]
# # Objectives
#
# • Transform raw sales data into meaningful visualizations.
#
# • Identify sales and profit trends.
#
# • Analyze regional and category performance.
#
# • Create visual stories that support business decisions.
#
# • Build a portfolio project using data visualization techniques.

# %% [markdown]
# # Business Questions
#
# 1. Which category generates the highest sales?
# 2. Which region performs the best?
# 3. Which customer segment contributes the most revenue?
# 4. How do discounts affect profit?
# 5. What are the yearly sales trends?
# 6. Which states generate the highest sales?
# 7. Which shipping mode is most commonly used?

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("Superstore_Sales_Dataset.csv")

df.head()
# Out:
#      OrderID Region      Segment      ShipMode    Category  SubCategory  \
# 0  ORD-10001   West  Home Office   First Class  Technology     Machines
# 1  ORD-10002  South    Corporate  Second Class   Furniture  Furnishings
# 2  ORD-10003   East  Home Office   First Class   Furniture       Chairs
# 3  ORD-10004  South     Consumer   First Class  Technology  Accessories
# 4  ORD-10005   West    Corporate  Second Class  Technology       Phones
#
#      Sales  Quantity  Discount  Profit  OrderYear     State
# 0  1902.41         8       0.0  320.71       2021  New York
# 1   302.88         3       0.1  -22.60       2020   Florida
# 2   622.40         6       0.0   58.74       2025     Texas
# 3   199.40         3       0.3   26.20       2023  New York
# 4   911.99         2       0.3  295.48       2019     Texas

# %% [markdown]
# # Dataset Overview

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      2000 non-null   str
#  1   Region       2000 non-null   str
#  2   Segment      2000 non-null   str
#  3   ShipMode     2000 non-null   str
#  4   Category     2000 non-null   str
#  5   SubCategory  2000 non-null   str
#  6   Sales        2000 non-null   float64
#  7   Quantity     2000 non-null   int64
#  8   Discount     2000 non-null   float64
#  9   Profit       2000 non-null   float64
#  10  OrderYear    2000 non-null   int64
#  11  State        2000 non-null   str
# dtypes: float64(3), int64(2), str(7)
# memory usage: 306.9 KB
#              Sales     Quantity     Discount       Profit    OrderYear
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean   1027.352530     4.908500     0.146600   127.656220  2021.985000
# ...

# %% [markdown]
# # Sales by Category

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='Category', y='Sales', data=df)
plt.title('Sales by Category')
plt.show()

# %% [markdown]
# # Profit by Category

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='Category', y='Profit', data=df)
plt.title('Profit by Category')
plt.show()

# %% [markdown]
# # Sales by Region

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='Region', y='Sales', data=df)
plt.title('Sales by Region')
plt.show()

# %% [markdown]
# # Customer Segment Analysis

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='Segment', data=df)
plt.title('Customer Segments')
plt.show()

# %% [markdown]
# # Discount vs Profit

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='Discount', y='Profit', data=df)
plt.title('Discount vs Profit')
plt.show()

# %% [markdown]
# # Sales Trend by Year

# %%
yearly_sales = df.groupby('OrderYear')['Sales'].sum()

yearly_sales.plot(marker='o')
plt.title('Yearly Sales Trend')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Ship Mode Analysis

# %%
sns.countplot(x='ShipMode', data=df)
plt.xticks(rotation=20)
plt.title('Shipping Mode Distribution')
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Data Storytelling
#
# • Technology products generate high sales.
#
# • Some regions contribute more revenue than others.
#
# • Higher discounts can reduce profit.
#
# • Certain customer segments contribute significantly to sales.
#
# • Sales show variation across years.

# %% [markdown]
# # Key Insights
#
# • The most profitable category was identified.
#
# • Regional sales performance was analyzed.
#
# • Customer purchasing patterns were observed.
#
# • Discounts have an impact on profitability.
#
# • Shipping preferences were identified.

# %% [markdown]
# # Conclusion
#
# The visualizations successfully transformed raw sales data into meaningful business insights. The analysis revealed important trends in sales, profit, customer segments, and regional performance. These findings can help businesses make informed decisions and improve overall performance.
